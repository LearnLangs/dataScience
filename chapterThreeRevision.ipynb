# %%
x= True
y= False

print(not(x and y))

"""This prints True because the Logical operator would return False because one of the variable if False"""
# Out:
# True

# %%
x = 104
x %= 3
"""this would return a value of 2 because 3 can divide 104 34 times remainig 2"""
print(x)
# Out:
# 2

# %%
104 % 3
# Out:
# 2

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
"""Notice the output above did not include 5, this was because it started from 0 and looped 5 times"""
# to include values from 1 to 5
for i in range(5):
    print(i+1)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
"""Use while loop when you don't know the number of times the iteration would be"""
# same example but i want from 1 to 5

i = 0
while i < 5:
    print(i+1)
    # now need to update the figure of i else we will have a run time error. because its never going to stop print unless we stop it
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# square root formula
x = 25
while True:
    a = x - 1
    y = (a + x/a)/2.0
    if y == a:
        print (y)
        break
    a = y
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 3
#       1 # square root formula
#       2 x = 25
# ----> 3 while True:
#       4     a = x - 1
#       5     y = (a + x/a)/2.0
#
# KeyboardInterrupt:
